# %%
import seaborn as sns
import matplotlib.pyplot as plt

import numpy as np
import pandas as pd

# %%
# effective parameter growth

data = [["Multi-Stage Sequential", (128, 128), 1, 409600], 
        ["Multi-Stage Sequential", (128, 128), 2, 2457600], 
        ["Multi-Stage Sequential", (128, 128), 3, 6144000], 
        ["Multi-Stage Sequential", (128, 128), 4, 11468800], 
        ["Multi-Stage Sequential", (128, 128), 5, 18432000], 
        ["Multi-Stage Sequential", (128, 128), 6, 27033600],
        ["Multi-Stage Sequential", (256, 256), 1, 1638400], 
        ["Multi-Stage Sequential", (256, 256), 2, 9830400],
        ["Multi-Stage Sequential", (256, 256), 3, 24576000],
        ["Multi-Stage Sequential", (256, 256), 4, 45875200],
        ["Multi-Stage Sequential", (256, 256), 5, 73728000],
        ["Multi-Stage Sequential", (256, 256), 6, 108134400],
        ["Simultaneous", (128, 128), 1, 409600],
        ["Simultaneous", (128, 128), 2, 4096000],
        ["Simultaneous", (128, 128), 3, 30720000],
        ["Simultaneous", (128, 128), 4, 204800000],
        ["Simultaneous", (128, 128), 5, 1280000000],
        ["Simultaneous", (128, 128), 6, 7680000000],
        ["Simultaneous", (256, 256), 1, 1638400],
        ["Simultaneous", (256, 256), 2, 16384000],
        ["Simultaneous", (256, 256), 3, 122880000],
        ["Simultaneous", (256, 256), 4, 819200000],
        ["Simultaneous", (256, 256), 5, 5120000000],
        ["Simultaneous", (256, 256), 6, 30720000000]]

df = pd.DataFrame(data, columns = ["Algorithm", "Hidden layer sizes", "Nr. of Agents", "Parameters"])

# %%
df
# Out:
#                  Algorithm Hidden layer sizes  Nr. of Agents   Parameters
# 0   Multi-Stage Sequential         (128, 128)              1       409600
# 1   Multi-Stage Sequential         (128, 128)              2      2457600
# 2   Multi-Stage Sequential         (128, 128)              3      6144000
# 3   Multi-Stage Sequential         (128, 128)              4     11468800
# 4   Multi-Stage Sequential         (128, 128)              5     18432000
# 5   Multi-Stage Sequential         (128, 128)              6     27033600
# 6   Multi-Stage Sequential         (256, 256)              1      1638400
# 7   Multi-Stage Sequential         (256, 256)              2      9830400
# 8   Multi-Stage Sequential         (256, 256)              3     24576000
# 9   Multi-Stage Sequential         (256, 256)              4     45875200
# 10  Multi-Stage Sequential         (256, 256)              5     73728000
# 11  Multi-Stage Sequential         (256, 256)              6    108134400
# ...

# %%
sns.reset_defaults()

# %%
plt.figure()

sns.set_theme(style = "whitegrid")

colors = ["#6DDA6A", "#f3474b"]
sns.set_palette(sns.color_palette("Set2"))

g = sns.catplot(kind = "bar", 
                data = df[(df["Hidden layer sizes"] == (128,128))], 
                x = "Nr. of Agents", 
                y = "Parameters", 
                hue = "Algorithm",
                # width = 0.8,
                # height = 4,
                aspect = 1)

sns.move_legend(
    g, "lower center",
    bbox_to_anchor=(0.3, 0.8), ncol=1, title = None, frameon=False,
)


g.fig.get_axes()[0].set_yscale('log')
g.set(ylim = [0, np.power(10, 10)])

ax = g.facet_axis(0, 0) 

# for idx, c in enumerate(ax.patches):
    # labels = [f' {(v.get_height() / 1000000):.1f}M' for v in c]
for idx, c in enumerate(ax.patches):
    # labels = f' {(c.get_height() / 1000000):.1f}M'
    # ax.bar_label(c, labels=labels, label_type='edge', rotation = 90, fontsize = 12, padding = -60)

    if idx in [0]:
        height = c.get_height()
        # ax.text(c.get_x() + c.get_width() / 2, height + 5, f' {(height / 1000000):.1f}M',
        ax.text((c.get_x() + c.get_width() / 2) - 0.1, height, f' {(height / 1000000):.1f}M',
                rotation = 90, color = "darkgreen")
    if idx in [1]:
        height = c.get_height()
        ax.text((c.get_x() + c.get_width() / 2) - 0.1, height - 1800000, f' {(height / 1000000):.1f}M',
                rotation = 90, color = "darkgreen")
    if idx in [2]:
        height = c.get_height()
        ax.text((c.get_x() + c.get_width() / 2) - 0.1, height - 4500000, f' {(height / 1000000):.1f}M',
                rotation = 90, color = "darkgreen")
    if idx in [3]:
        height = c.get_height()
        ax.text((c.get_x() + c.get_width() / 2) - 0.1, height - 9200000, f' {(height / 1000000):.1f}M',
                rotation = 90, color = "darkgreen")
    if idx in [4]:
        height = c.get_height()
        ax.text((c.get_x() + c.get_width() / 2) - 0.1, height - 14800000, f' {(height / 1000000):.1f}M',
                rotation = 90, color = "darkgreen")
    if idx in [5]:
        height = c.get_height()
        ax.text((c.get_x() + c.get_width() / 2) - 0.1, height - 21500000, f' {(height / 1000000):.1f}M',
                rotation = 90, color = "darkgreen")
        
    if idx in [6]:
        height = c.get_height()
        ax.text((c.get_x() + c.get_width() / 2) - 0.1, height, f' {(height / 1000000):.1f}M',
                rotation = 90, color = "darkred")
    if idx in [7]:
        height = c.get_height()
        ax.text((c.get_x() + c.get_width() / 2) - 0.1, height - 3000000, f' {(height / 1000000):.1f}M',
                rotation = 90, color = "darkred")
    if idx in [8]:
        height = c.get_height()
        ax.text((c.get_x() + c.get_width() / 2) - 0.1, height - 24500000, f' {(height / 1000000):.1f}M',
                rotation = 90, color = "darkred")
    if idx in [9]:
        height = c.get_height()
        ax.text((c.get_x() + c.get_width() / 2) - 0.1, height - 175000000, f' {(height / 1000000):.1f}M',
                rotation = 90, color = "darkred")
    if idx in [10]:
        height = c.get_height()
        ax.text((c.get_x() + c.get_width() / 2) - 0.1, height - 930000000, f' {(height / 1000000000):.1f}B',
                rotation = 90, color = "darkred")
    if idx in [11]:
        height = c.get_height()
        ax.text((c.get_x() + c.get_width() / 2) - 0.1, height - 5500000000, f' {(height / 1000000000):.1f}B',
                rotation = 90, color = "darkred")
# Out:
# /home/hkolstee/.local/lib/python3.10/site-packages/seaborn/axisgrid.py:44: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax.set(**kwargs)

# %%
g.savefig('plots/param_growth.png', dpi = 300)

# %%
plt.figure()

sns.set_theme(style = "whitegrid")

colors = ["#6DDA6A", "#f3474b"]
sns.set_palette(sns.color_palette("Set2"))

g = sns.catplot(kind = "bar", 
                data = df[(df["Hidden layer sizes"] == (128,128))], 
                x = "Nr. of Agents", 
                y = "Parameters", 
                hue = "Algorithm",
                width = 0.7,
                height = 4,
                aspect = 1000/600)
# )
sns.move_legend(
    g, "lower center",
    bbox_to_anchor=(0.25, 0.85), ncol=1, title = None, frameon=False,
)


g.fig.get_axes()[0].set_yscale('log')
g.set(ylim = [0, np.power(10, 10)])

ax = g.facet_axis(0, 0) 

# for idx, c in enumerate(ax.patches):
    # labels = [f' {(v.get_height() / 1000000):.1f}M' for v in c]
for idx, c in enumerate(ax.patches):
    # labels = f' {(c.get_height() / 1000000):.1f}M'
    # ax.bar_label(c, labels=labels, label_type='edge', rotation = 90, fontsize = 12, padding = -60)

    if idx in [0]:
        height = c.get_height()
        # ax.text(c.get_x() + c.get_width() / 2, height + 5, f' {(height / 1000000):.1f}M',
        ax.text((c.get_x() + c.get_width() / 2) - 0.065, height, f' {(height / 1000000):.1f}M',
                rotation = 90, color = "darkgreen")
    if idx in [1]:
        height = c.get_height()
        ax.text((c.get_x() + c.get_width() / 2) - 0.065, height , f' {(height / 1000000):.1f}M',
                rotation = 90, color = "darkgreen")
    if idx in [2]:
        height = c.get_height()
        ax.text((c.get_x() + c.get_width() / 2) - 0.065, height , f' {(height / 1000000):.1f}M',
                rotation = 90, color = "darkgreen")
    if idx in [3]:
        height = c.get_height()
        ax.text((c.get_x() + c.get_width() / 2) - 0.065, height , f' {(height / 1000000):.1f}M',
                rotation = 90, color = "darkgreen")
    if idx in [4]:
        height = c.get_height()
        ax.text((c.get_x() + c.get_width() / 2) - 0.065, height , f' {(height / 1000000):.1f}M',
                rotation = 90, color = "darkgreen")
    if idx in [5]:
        height = c.get_height()
        ax.text((c.get_x() + c.get_width() / 2) - 0.065, height , f' {(height / 1000000):.1f}M',
                rotation = 90, color = "darkgreen")
        
    if idx in [6]:
        height = c.get_height()
        ax.text((c.get_x() + c.get_width() / 2) - 0.065, height, f' {(height / 1000000):.1f}M',
                rotation = 90, color = "darkred")
    if idx in [7]:
        height = c.get_height()
        ax.text((c.get_x() + c.get_width() / 2) - 0.065, height , f' {(height / 1000000):.1f}M',
                rotation = 90, color = "darkred")
    if idx in [8]:
        height = c.get_height()
        ax.text((c.get_x() + c.get_width() / 2) - 0.065, height , f' {(height / 1000000):.1f}M',
                rotation = 90, color = "darkred")
    if idx in [9]:
        height = c.get_height()
        ax.text((c.get_x() + c.get_width() / 2) - 0.065, height , f' {(height / 1000000):.1f}M',
                rotation = 90, color = "darkred")
    if idx in [10]:
        height = c.get_height()
        ax.text((c.get_x() + c.get_width() / 2) - 0.065, height , f' {(height / 1000000):.1f}M',
                rotation = 90, color = "darkred")
    if idx in [11]:
        height = c.get_height()
        ax.text((c.get_x() + c.get_width() / 2) - 0.065, height , f' {(height / 1000000):.1f}M',
                rotation = 90, color = "darkred")
# Out:
# /home/hkolstee/.local/lib/python3.10/site-packages/seaborn/axisgrid.py:44: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax.set(**kwargs)

# %%
g.savefig('plots/param_growth2.png', dpi = 300)

# %%
plt.figure()

sns.set_theme(style = "whitegrid")

colors = ["#80BAD6", "#ECB47C"]
sns.set_palette(sns.color_palette("Set2"))

g = sns.catplot(kind = "bar", 
                data = df[df["Hidden layer sizes"] == (256, 256)], 
                x = "Nr. of Agents", 
                y = "Parameters", 
                hue = "Algorithm",
                # width = 0.8,
                # height = 4,
                aspect = 1)
# )
sns.move_legend(
    g, "lower center",
    bbox_to_anchor=(0.36, 0.8), ncol=1, title = None, frameon=False,
)


g.fig.get_axes()[0].set_yscale('log')
g.set(ylim = [0, np.power(10, 11)])

ax = g.facet_axis(0, 0) 

# for idx, c in enumerate(ax.patches):
    # labels = [f' {(v.get_height() / 1000000):.1f}M' for v in c]
for idx, c in enumerate(ax.patches):
    # labels = f' {(c.get_height() / 1000000):.1f}M'
    # ax.bar_label(c, labels=labels, label_type='edge', rotation = 90, fontsize = 12, padding = -60)

    if idx in [0]:
        height = c.get_height()
        # ax.text(c.get_x() + c.get_width() / 2, height + 5, f' {(height / 1000000):.1f}M',
        ax.text((c.get_x() + c.get_width() / 2) - 0.1, height, f' {(height / 1000000):.1f}M',
                rotation = 90, color = "darkgreen")
    if idx in [1]:
        height = c.get_height()
        ax.text((c.get_x() + c.get_width() / 2) - 0.1, height - 7500000, f' {(height / 1000000):.1f}M',
                rotation = 90, color = "darkgreen")
    if idx in [2]:
        height = c.get_height()
        ax.text((c.get_x() + c.get_width() / 2) - 0.1, height - 20300000, f' {(height / 1000000):.1f}M',
                rotation = 90, color = "darkgreen")
    if idx in [3]:
        height = c.get_height()
        ax.text((c.get_x() + c.get_width() / 2) - 0.1, height - 38500000, f' {(height / 1000000):.1f}M',
                rotation = 90, color = "darkgreen")
    if idx in [4]:
        height = c.get_height()
        ax.text((c.get_x() + c.get_width() / 2) - 0.1, height - 62000000, f' {(height / 1000000):.1f}M',
                rotation = 90, color = "darkgreen")
    if idx in [5]:
        height = c.get_height()
        ax.text((c.get_x() + c.get_width() / 2) - 0.1, height - 95500000, f' {(height / 1000000):.1f}M',
                rotation = 90, color = "darkgreen")
        
    if idx in [6]:
        height = c.get_height()
        ax.text((c.get_x() + c.get_width() / 2) - 0.1, height, f' {(height / 1000000):.1f}M',
                rotation = 90, color = "darkred")
    if idx in [7]:
        height = c.get_height()
        ax.text((c.get_x() + c.get_width() / 2) - 0.1, height - 13600000, f' {(height / 1000000):.1f}M',
                rotation = 90, color = "darkred")
    if idx in [8]:
        height = c.get_height()
        ax.text((c.get_x() + c.get_width() / 2) - 0.1, height - 108000000, f' {(height / 1000000):.1f}M',
                rotation = 90, color = "darkred")
    if idx in [9]:
        height = c.get_height()
        ax.text((c.get_x() + c.get_width() / 2) - 0.1, height - 715000000, f' {(height / 1000000):.1f}M',
                rotation = 90, color = "darkred")
    if idx in [10]:
        height = c.get_height()
        ax.text((c.get_x() + c.get_width() / 2) - 0.1, height - 3800000000, f' {(height / 1000000000):.1f}B',
                rotation = 90, color = "darkred")
    if idx in [11]:
        height = c.get_height()
        ax.text((c.get_x() + c.get_width() / 2) - 0.1, height - 25500000000, f' {(height / 1000000000):.1f}B',
                rotation = 90, color = "darkred")
# Out:
# /home/hkolstee/.local/lib/python3.10/site-packages/seaborn/axisgrid.py:44: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax.set(**kwargs)

# %%
g.savefig('plots/param_growth3.png', dpi = 300)
