# %%
# custom imports
from custom_agents.CTCE_algorithms.centralized_DQN import DQN

# custom meeting environment
from custom_meeting_env.meeting_env.envs.grid_MA_meeting import grid_meeting_env
from custom_meeting_env.meeting_env.wrappers.pettingzoo_wrapper import PettingZooWrapper

env = grid_meeting_env(preset = 7)

    # pettingzoo conversion + normalization wrappper
env = PettingZooWrapper(env, normalize = True)
    
    # create model
dqn = DQN(env, lr = 0.000001, batch_size = 256, layer_sizes = (128, 128), eps_steps = 1000000, global_observations = True, buffer_max_size = 1000000, tau = 0.00001) 
    
    # train agent (ep = 720)
dqn.train(num_episodes = 30000000)
# Out:
# 2024-10-09 14:34:38.981104: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Episode: 0 - Reward:-0.03000000000000002 - Avg loss (last ep): None
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 17
#      14 dqn = DQN(env, lr = 0.000001, batch_size = 256, layer_sizes = (128, 128), eps_steps = 1000000, global_observations = True, buffer_max_size = 1000000, tau = 0.00001)
#      16     # train agent (ep = 720)
# ---> 17 dqn.train(num_episodes = 30000000)
#
# File ~/masterThesis/custom_agents/CTCE_algorithms/centralized_DQN.py:254, in DQN.train(self, num_episodes)
# ...

# %%
import sys
from os import path

# custom imports
from custom_agents.CTCE_algorithms.ma_sac_agents_seq_id import Agents

# custom spider fly environment
from custom_spread_env.pettingzoo.mpe import simple_spread_v3
from custom_spider_env.spider_fly_env.wrappers.pettingzoo_wrapper import PettingZooWrapper

env = simple_spread_v3.parallel_env(continuous_actions = True, N = 2)

# pettingzoo conversion + normalization wrappper
env = PettingZooWrapper(env)

# create model
sac_agents = Agents(env, batch_size = 256, layer_sizes = (128, 128), global_observations = True) 

# train agent (ep = 720)
sac_agents.train(nr_steps = 300000000, warmup_steps = 1000)
# Out:
# 2024-09-23 22:31:52.817827: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 20
#      17 sac_agents = Agents(env, batch_size = 256, layer_sizes = (128, 128), global_observations = True)
#      19 # train agent (ep = 720)
# ---> 20 sac_agents.train(nr_steps = 300000000, warmup_steps = 1000)
#
# File ~/masterThesis/custom_agents/CTCE_algorithms/ma_sac_agents_seq_id.py:568, in Agents.train(self, nr_steps, max_episode_len, warmup_steps, learn_delay, learn_freq, learn_weight, checkpoint, save_dir)
#     565 if step > learn_delay and step % learn_freq == 0:
# ...

# %%
import sys
from os import path

# custom imports
from custom_agents.CTCE_algorithms.shared_seq_DQN import seqDQN

# custom spider fly environment
from custom_spider_env.spider_fly_env.envs.grid_MA_pettingzoo import SpiderFlyEnvMA
from custom_spider_env.spider_fly_env.wrappers.pettingzoo_wrapper import PettingZooWrapper

env = SpiderFlyEnvMA(size = 4, spiders = 3, max_timesteps = 100)

# pettingzoo conversion + normalization wrappper
env = PettingZooWrapper(env, normalize = True)

# create model
dqn = seqDQN(env, lr = 1e-3, batch_size = 256, layer_sizes = (128, 128), eps_steps = 1000000, global_observations = True, buffer_max_size = 1000000, tau = 0.001) 

# train agent (ep = 720)
dqn.train(num_episodes = 300000000)
# Out:
# 2024-09-24 12:42:15.882219: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /home/hkolstee/.local/lib/python3.10/site-packages/gymnasium/envs/registration.py:694: UserWarning: WARN: Overriding environment SpiderFlyGrid-v0 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")
# /home/hkolstee/.local/lib/python3.10/site-packages/gymnasium/envs/registration.py:694: UserWarning: WARN: Overriding environment SpiderFlyGridMA-v0 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")
# Episode: 0 - Reward:[0.921 0.931 0.935] - Avg loss (last ep): None
# ---------------------------------------------------------------------------
# ...

# %%
import sys
import os
import shutil

# remove log/model files
if os.path.isdir("tensorboard_logs"):
    shutil.rmtree("tensorboard_logs")
    shutil.rmtree("models")

# custom imports
# from custom_agents.CTCE_algorithms.ma_sac_agents_seq_discrete import Agents
from custom_agents.CTCE_algorithms.centralized_SAC_discrete import SAC

# custom meeting environment
from custom_meeting_env.meeting_env.envs.grid_MA_meeting import grid_meeting_env
from custom_meeting_env.meeting_env.wrappers.pettingzoo_wrapper import PettingZooWrapper

env = grid_meeting_env(preset = 5)

# pettingzoo conversion + normalization wrappper
env = PettingZooWrapper(env, normalize = True)

# create model
# agents = Agents(env, lr_actor = 0.0003, lr_critic = 0.0003, layer_sizes = (128, 128), global_observations = True, alpha_temp_multiplier = 3)
agents = SAC(env, layer_sizes = (128, 128), lr_actor = 0.0003, lr_critic = 0.0003, global_obs = True, polyak = 0.995, alpha_temp_multiplier = 3)

# train agent (ep = 720)
agents.train(nr_eps = 10000000, warmup_steps = 300000, learn_delay = 300000)
# agents.train(nr_steps = 1000000000)
# agents.train(nr_steps = 1000000000, warmup_steps = 30000, learn_delay = 100, learn_freq = 200)
# agents.train(nr_steps = 1000000000, warmup_steps = 300000, learn_delay = 300000)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 31
#      24 agents = Agents(env, lr_actor = 0.0003, lr_critic = 0.0003, layer_sizes = (128, 128), global_observations = True, alpha_temp_multiplier = 3)
#      25 # agents = Agents(env, lr_actor = 0.003, lr_critic = 0.0003, layer_sizes = (128, 128), alpha_temp_multiplier = 0.5, global_obs = True)
#      26 # agents = SAC(env, layer_sizes = (128, 128), lr_actor = 0.0003, lr_critic = 0.0003, global_obs = True, polyak = 0.995, alpha_temp_multiplier = 1)
#      27
#      28 # train agent (ep = 720)
#      29 # agents.train(nr_steps = 1000000000)
#      30 # agents.train(nr_steps = 1000000000, warmup_steps = 30000, learn_delay = 100, learn_freq = 200)
# ---> 31 agents.train(nr_steps = 1000000000, warmup_steps = 300000, learn_delay = 300000)
#
# ...

# %%
import sys
from os import path

# custom imports
from custom_agents.CTCE_algorithms.ma_sac_agents_seq_id import Agents

# custom spider fly environment
from custom_spread_env.pettingzoo.mpe import simple_spread_v3
from custom_spider_env.spider_fly_env.wrappers.pettingzoo_wrapper import PettingZooWrapper

env = simple_spread_v3.parallel_env(continuous_actions = True, N = 3)

# pettingzoo conversion + normalization wrappper
env = PettingZooWrapper(env)

# create model
sac_agents = Agents(env, lr_actor = 0.0003, lr_critic = 0.0003, batch_size = 256, polyak = 0.99825, layer_sizes = (256, 256), global_observations = True) 

# train agent (ep = 720)
sac_agents.train(nr_steps = 300000000, warmup_steps = 10000)
# Out:
# 2024-10-01 12:29:08.073963: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 20
#      17 sac_agents = Agents(env, lr_actor = 0.0003, lr_critic = 0.0003, batch_size = 256, polyak = 0.99825, layer_sizes = (256, 256), global_observations = True)
#      19 # train agent (ep = 720)
# ---> 20 sac_agents.train(nr_steps = 300000000, warmup_steps = 10000)
#
# File ~/masterThesis/custom_agents/CTCE_algorithms/ma_sac_agents_seq_id.py:568, in Agents.train(self, nr_steps, max_episode_len, warmup_steps, learn_delay, learn_freq, learn_weight, checkpoint, save_dir)
# ...
